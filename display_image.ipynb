# %%
from IPython.display import Image
#!find test/ -printf '%T+ %p\n' | sort -r | head
#!ls test/ -tp | grep -v /$ | head -1
import glob
import os, cv2

list_of_files = glob.glob('test/*') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
#latest_file = 'detected.jpg'
#latest_file = min(list_of_files, key=os.path.getctime)
#latest_file = '/tf/notebooks/datasets/07_object_detection/val/ZED3_KSC_052263_L_P012028.png'
print(latest_file)
#path_im = 'test/4c9518e4815b486097a2f71d6216647f.jpg'
im = cv2.imread(latest_file)
height, width = im.shape[:2]
print('width : ', width, ', height', height)
Image(filename=latest_file)
# Out:
# test/23b6843278d14f3d85840b588118dca7.jpg
# width :  512 , height 512
